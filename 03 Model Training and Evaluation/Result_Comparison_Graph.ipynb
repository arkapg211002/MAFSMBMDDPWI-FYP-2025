# %%
import numpy as np
import matplotlib.pyplot as plt

# Data
algorithms = ['Logistic Regression', 'Naive Bayes', 'SVM', 'Random Forest', 'XGBoost', 'KNN', 'LSTM']
accuracy = [87.66, 83.63, 85.13, 86.00, 87.39, 54.46, 83.55]
precision = [87.0, 85.0, 85.0, 86.0, 87.0, 67.0, 84.0]
recall = [88.0, 84.0, 85.0, 86.0, 87.0, 54.0, 84.0]
f1_score = [87.0, 84.0, 85.0, 85.0, 87.0, 56.0, 84.0]
support = [99.81, 99.81, 99.81, 99.81, 100.0, 99.81, 100.0]

# Bar width
width = 0.15

# X-axis positions
x = np.arange(len(algorithms))

# Set figure size
plt.figure(figsize=(16, 9))  # Increased size for clarity

# Plot bars with distinct offsets
plt.bar(x - 2*width, accuracy, width, label='Accuracy', color='skyblue', edgecolor='black')
plt.bar(x - width, precision, width, label='Precision', color='orange', edgecolor='black')
plt.bar(x, recall, width, label='Recall', color='green', edgecolor='black')
plt.bar(x + width, f1_score, width, label='F1-Score', color='red', edgecolor='black')
plt.bar(x + 2*width, support, width, label='Support (Normalized)', color='purple', edgecolor='black')

# Titles and labels
plt.title('Comparison of Metrics Across Algorithms', fontsize=16, weight='bold', pad=20)
plt.ylabel('Scores (%)', fontsize=14)
plt.xlabel('Algorithms', fontsize=14)
plt.xticks(x, algorithms, rotation=45, ha="right", fontsize=12)

# Add grid for better readability
plt.grid(axis='y', linestyle='--', alpha=0.7)

# Add legend outside the plot
plt.legend(fontsize=12, loc='upper left', bbox_to_anchor=(1.05, 1))

# Add values on top of the bars
def add_labels(values, positions, offset, color):
    for i, v in enumerate(values):
        plt.text(positions[i] + offset, v + 1.5, f"{v:.1f}", ha='center', va='bottom', fontsize=10, color=color)

add_labels(accuracy, x, -2*width, 'black')
add_labels(precision, x, -width, 'black')
add_labels(recall, x, 0, 'black')
add_labels(f1_score, x, width, 'black')
add_labels(support, x, 2*width, 'black')

# Adjust layout to prevent clipping
plt.tight_layout()
plt.subplots_adjust(right=0.8)  # Add space for the legend

# Show the plot
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# Data
algorithms = ['Logistic Regression', 'Naive Bayes', 'SVM', 'Random Forest', 'XGBoost', 'KNN', 'LSTM']
metrics = ['Accuracy', 'Precision', 'Recall', 'F1-Score', 'Support']
values = np.array([
    [87.66, 83.63, 85.13, 86.00, 87.39, 54.46, 83.55],  # Accuracy
    [87.0, 85.0, 85.0, 86.0, 87.0, 67.0, 84.0],         # Precision
    [88.0, 84.0, 85.0, 86.0, 87.0, 54.0, 84.0],         # Recall
    [87.0, 84.0, 85.0, 85.0, 87.0, 56.0, 84.0],         # F1-Score
    [99.81, 99.81, 99.81, 99.81, 100.0, 99.81, 100.0]   # Support
])

# Transpose for horizontal bars
values = values.T

# Create horizontal bar chart
fig, ax = plt.subplots(figsize=(14, 8))

# Bar positions and width
bar_positions = np.arange(len(algorithms))
bar_width = 0.15

# Plot bars for each metric
colors = ['skyblue', 'orange', 'green', 'red', 'purple']
for i, metric in enumerate(metrics):
    ax.barh(bar_positions + i * bar_width, values[:, i], bar_width, label=metric, color=colors[i], edgecolor='black')

# Add labels and titles
ax.set_yticks(bar_positions + bar_width * 2)  # Center labels
ax.set_yticklabels(algorithms, fontsize=12)
ax.set_title('Comparison of Metrics Across Algorithms', fontsize=16, weight='bold', pad=20)
ax.set_xlabel('Scores (%)', fontsize=14)
ax.set_xlim(0, 120)  # Adjust for all values (including support normalized to %)
ax.grid(axis='x', linestyle='--', alpha=0.7)

# Add legends and improve layout
ax.legend(fontsize=12, loc='upper right')
plt.tight_layout()

# Show plot
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# Data
algorithms = ['Logistic Regression', 'Naive Bayes', 'SVM', 'Random Forest', 'XGBoost', 'KNN', 'LSTM']
accuracy = [87.66, 83.63, 85.13, 86.00, 87.39, 54.46, 83.55]
precision = [87.0, 85.0, 85.0, 86.0, 87.0, 67.0, 84.0]
recall = [88.0, 84.0, 85.0, 86.0, 87.0, 54.0, 84.0]
f1_score = [87.0, 84.0, 85.0, 85.0, 87.0, 56.0, 84.0]
support = [99.81, 99.81, 99.81, 99.81, 100.0, 99.81, 100.0]

# Bar width
width = 0.15

# X-axis positions
x = np.arange(len(algorithms))

# Set figure size
plt.figure(figsize=(16, 9))  # Increased size for clarity

# Plot bars with distinct offsets
plt.bar(x - 2*width, accuracy, width, label='Accuracy', color='skyblue', edgecolor='black')
plt.bar(x - width, precision, width, label='Precision', color='orange', edgecolor='black')
plt.bar(x, recall, width, label='Recall', color='green', edgecolor='black')
plt.bar(x + width, f1_score, width, label='F1-Score', color='red', edgecolor='black')
plt.bar(x + 2*width, support, width, label='Support (Normalized)', color='purple', edgecolor='black')

# Titles and labels
plt.title('Comparison of Metrics Across Algorithms', fontsize=16, weight='bold', pad=20)
plt.ylabel('Scores (%)', fontsize=14)
plt.xlabel('Algorithms', fontsize=14)
plt.xticks(x, algorithms, rotation=45, ha="right", fontsize=12)

# Add grid for better readability
plt.grid(axis='y', linestyle='--', alpha=0.7)

# Add legend outside the plot
plt.legend(fontsize=12, loc='upper left', bbox_to_anchor=(1.05, 1))

# Add values on top of the bars
def add_labels(values, positions, offset, color):
    for i, v in enumerate(values):
        plt.text(
            positions[i] + offset, v + 1.5, f"{v:.1f}",
            ha='center', va='bottom', fontsize=10, color=color, rotation=90
        )

add_labels(accuracy, x, -2*width, 'black')
add_labels(precision, x, -width, 'black')
add_labels(recall, x, 0, 'black')
add_labels(f1_score, x, width, 'black')
add_labels(support, x, 2*width, 'black')

# Adjust layout to prevent clipping
plt.ylim(0, 110)
plt.tight_layout()
plt.subplots_adjust(right=0.8)  # Add space for the legend

# Show the plot
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
import textwrap

# Data for algorithms after hyperparameter tuning
algorithms = ['Logistic Regression', 'Naive Bayes', 'SVM', 'KNN']
accuracy = [87.72, 83.95, 85.13, 52.03]  # From accuracy values
precision = [87.0, 85.0, 85.0, 66.0]  # Weighted avg precision
recall = [88.0, 84.0, 85.0, 52.0]  # Weighted avg recall
f1_score = [87.0, 84.0, 85.0, 53.0]  # Weighted avg F1
support = [99.81, 99.81, 99.81, 99.81]  # Total support (normalized)

# Best hyperparameters for each algorithm
best_params = [
    "{'solver': 'liblinear', 'penalty': 'l2', 'C': 1}",  # Logistic Regression
    "{'alpha': 0.2914}",  # Naive Bayes
    "{'kernel': 'linear', 'gamma': 'scale', 'C': 1}",  # SVM
    "{'weights': 'distance', 'n_neighbors': 10, 'metric': 'euclidean}"  # KNN
]

# Bar width
width = 0.15

# X-axis positions
x = np.arange(len(algorithms))

# Set figure size
plt.figure(figsize=(16, 9))  # Increased size for clarity

# Plot bars with distinct offsets
plt.bar(x - 2*width, accuracy, width, label='Accuracy', color='skyblue', edgecolor='black')
plt.bar(x - width, precision, width, label='Precision', color='orange', edgecolor='black')
plt.bar(x, recall, width, label='Recall', color='green', edgecolor='black')
plt.bar(x + width, f1_score, width, label='F1-Score', color='red', edgecolor='black')
plt.bar(x + 2*width, support, width, label='Support (Normalized)', color='purple', edgecolor='black')

# Titles and labels
plt.title('Comparison of Metrics After Hyperparameter Tuning', fontsize=16, weight='bold', pad=20)
plt.ylabel('Scores (%)', fontsize=14)
plt.xlabel('Algorithms', fontsize=14)
plt.xticks(x, algorithms, rotation=45, ha="right", fontsize=12)

# Add grid for better readability
plt.grid(axis='y', linestyle='--', alpha=0.7)

# Add legend outside the plot
plt.legend(fontsize=12, loc='upper left', bbox_to_anchor=(1.05, 1))

# Add values on top of the bars
def add_labels(values, positions, offset, color):
    for i, v in enumerate(values):
        plt.text(positions[i] + offset, v + 1.5, f"{v:.1f}", ha='center', va='bottom', fontsize=10, color=color)

add_labels(accuracy, x, -2*width, 'black')
add_labels(precision, x, -width, 'black')
add_labels(recall, x, 0, 'black')
add_labels(f1_score, x, width, 'black')
add_labels(support, x, 2*width, 'black')

# Function to wrap the best hyperparameters text
def wrap_text(text, width=30):
    return "\n".join(textwrap.wrap(text, width=width))

# Annotating best hyperparameters (with word wrap)
y_position = -7  # Adjusted y position for the best parameters to be below the x-axis
for i, params in enumerate(best_params):
    # Apply word wrapping to the best parameters text
    wrapped_params = wrap_text(params, width=30)  # Adjust width as needed

    plt.text(x[i], y_position + y_offset, f"Best Params:\n{wrapped_params}", ha='center', va='top', fontsize=10, color='blue', rotation=0)

# Adjust layout to prevent clipping
plt.tight_layout()
plt.subplots_adjust(right=0.8)  # Add space for the legend

plt.xticks(rotation=0)

# Show the plot
plt.show()

# %%
import matplotlib.pyplot as plt

# Data for the models
classes = ["Anxiety", "Bipolar", "Depression", "Normal", "PTSD"]

# Metrics for each model
logistic_regression = {
    "precision": [0.83, 0.74, 0.76, 0.92, 0.87],
    "recall": [0.77, 0.55, 0.76, 0.99, 0.77],
    "f1_score": [0.80, 0.63, 0.76, 0.95, 0.82],
    "support": [379, 384, 373, 2183, 394],
}

xgboost = {
    "precision": [0.81, 0.77, 0.72, 0.93, 0.86],
    "recall": [0.74, 0.62, 0.81, 0.98, 0.75],
    "f1_score": [0.77, 0.69, 0.76, 0.95, 0.80],
    "support": [403, 397, 387, 2137, 396],
}

ensemble = {
    "precision": [0.96, 0.90, 0.95, 0.97, 0.98],
    "recall": [0.93, 0.86, 0.94, 0.99, 0.95],
    "f1_score": [0.95, 0.88, 0.94, 0.98, 0.96],
    "support": [1999, 1941, 1959, 10679, 1987],
}

# Create line plots
plt.figure(figsize=(12, 8))

# Precision
plt.plot(classes, logistic_regression["precision"], marker='o', label='LR Precision', color='b')
plt.plot(classes, xgboost["precision"], marker='o', label='XGBoost Precision', color='g')
plt.plot(classes, ensemble["precision"], marker='o', label='Ensemble Precision', color='r')

# Recall
plt.plot(classes, logistic_regression["recall"], marker='x', label='LR Recall', linestyle='--', color='b')
plt.plot(classes, xgboost["recall"], marker='x', label='XGBoost Recall', linestyle='--', color='g')
plt.plot(classes, ensemble["recall"], marker='x', label='Ensemble Recall', linestyle='--', color='r')

# F1 Score
plt.plot(classes, logistic_regression["f1_score"], marker='s', label='LR F1 Score', linestyle='-.', color='b')
plt.plot(classes, xgboost["f1_score"], marker='s', label='XGBoost F1 Score', linestyle='-.', color='g')
plt.plot(classes, ensemble["f1_score"], marker='s', label='Ensemble F1 Score', linestyle='-.', color='r')

# Support (scaled for visualization)
scaled_support = [x / max(ensemble["support"]) for x in logistic_regression["support"]]
plt.plot(classes, scaled_support, marker='d', label='LR Support (scaled)', linestyle=':', color='b')

scaled_support = [x / max(ensemble["support"]) for x in xgboost["support"]]
plt.plot(classes, scaled_support, marker='d', label='XGBoost Support (scaled)', linestyle=':', color='g')

scaled_support = [x / max(ensemble["support"]) for x in ensemble["support"]]
plt.plot(classes, scaled_support, marker='d', label='Ensemble Support (scaled)', linestyle=':', color='r')

# Add details
plt.title("Comparison of Metrics Across Models and Classes", fontweight="bold")
plt.xlabel("Classes", fontweight="bold")
plt.ylabel("Metrics / Scaled Support", fontweight="bold")
plt.legend()
plt.grid(True, linestyle='--', alpha=0.7)
plt.tight_layout()

# Show the plot
plt.show()

# %%
# ENSEMBLE MODEL ( SVM + LSTM )


import matplotlib.pyplot as plt

# Data for the models
classes = ["Anxiety", "Bipolar", "Depression", "Normal", "PTSD"]

# Metrics for each model
svm = {
    "precision": [0.72, 0.62, 0.74, 0.94, 0.78],
    "recall": [0.76, 0.61, 0.71, 0.95, 0.74],
    "f1_score": [0.74, 0.61, 0.72, 0.95, 0.76],
    "support": [379, 384, 373, 2183, 394],
}

lstm = {
    "precision": [0.81, 0.60, 0.56, 0.96, 0.76],
    "recall": [0.68, 0.59, 0.77, 0.96, 0.61],
    "f1_score": [0.74, 0.60, 0.65, 0.96, 0.68],
    "support": [403, 397, 387, 2137, 396],
}

ensemble = {
    "precision": [0.96, 0.94, 0.95, 0.98, 0.96],
    "recall": [0.95, 0.90, 0.95, 0.99, 0.96],
    "f1_score": [0.96, 0.92, 0.95, 0.99, 0.96],
    "support": [1999, 1941, 1959, 10679, 1987],
}

# Create line plots
plt.figure(figsize=(12, 8))

# Precision
plt.plot(classes, svm["precision"], marker='o', label='SVM Precision', color='b')
plt.plot(classes, lstm["precision"], marker='o', label='LSTM Precision', color='g')
plt.plot(classes, ensemble["precision"], marker='o', label='Ensemble Precision', color='r')

# Recall
plt.plot(classes, svm["recall"], marker='x', label='SVM Recall', linestyle='--', color='b')
plt.plot(classes, lstm["recall"], marker='x', label='LSTM Recall', linestyle='--', color='g')
plt.plot(classes, ensemble["recall"], marker='x', label='Ensemble Recall', linestyle='--', color='r')

# F1 Score
plt.plot(classes, svm["f1_score"], marker='s', label='SVM F1 Score', linestyle='-.', color='b')
plt.plot(classes, lstm["f1_score"], marker='s', label='LSTM F1 Score', linestyle='-.', color='g')
plt.plot(classes, ensemble["f1_score"], marker='s', label='Ensemble F1 Score', linestyle='-.', color='r')

# Support (scaled for visualization)
scaled_support = [x / max(ensemble["support"]) for x in svm["support"]]
plt.plot(classes, scaled_support, marker='d', label='SVM Support (scaled)', linestyle=':', color='b')

scaled_support = [x / max(ensemble["support"]) for x in lstm["support"]]
plt.plot(classes, scaled_support, marker='d', label='LSTM Support (scaled)', linestyle=':', color='g')

scaled_support = [x / max(ensemble["support"]) for x in ensemble["support"]]
plt.plot(classes, scaled_support, marker='d', label='Ensemble Support (scaled)', linestyle=':', color='r')

# Add details
plt.title("Comparison of Metrics Across Models and Classes", fontweight="bold")
plt.xlabel("Classes", fontweight="bold")
plt.ylabel("Metrics / Scaled Support", fontweight="bold")
plt.legend()
plt.grid(True, linestyle='--', alpha=0.7)
plt.tight_layout()

# Show the plot
plt.show()

# %%
import matplotlib.pyplot as plt

# Data for the models
classes = ["Anxiety", "Bipolar", "Depression", "Normal", "PTSD"]

# Metrics for each model
logistic_regression = {
    "precision": [0.83, 0.74, 0.76, 0.92, 0.87],
    "recall": [0.77, 0.55, 0.76, 0.99, 0.77],
    "f1_score": [0.80, 0.63, 0.76, 0.95, 0.82],
    "support": [379, 384, 373, 2183, 394],
}

xgboost = {
    "precision": [0.81, 0.77, 0.72, 0.93, 0.86],
    "recall": [0.74, 0.62, 0.81, 0.98, 0.75],
    "f1_score": [0.77, 0.69, 0.76, 0.95, 0.80],
    "support": [403, 397, 387, 2137, 396],
}

svm = {
    "precision": [0.72, 0.62, 0.74, 0.94, 0.78],
    "recall": [0.76, 0.61, 0.71, 0.95, 0.74],
    "f1_score": [0.74, 0.61, 0.72, 0.95, 0.76],
    "support": [379, 384, 373, 2183, 394],
}

lstm = {
    "precision": [0.81, 0.60, 0.56, 0.96, 0.76],
    "recall": [0.68, 0.59, 0.77, 0.96, 0.61],
    "f1_score": [0.74, 0.60, 0.65, 0.96, 0.68],
    "support": [403, 397, 387, 2137, 396],
}

ensemble = {
    "precision": [0.97, 0.95, 0.95, 0.98, 0.97],
    "recall": [0.96, 0.90, 0.96, 1.00, 0.96],
    "f1_score": [0.96, 0.92, 0.96, 0.99, 0.97],
    "support": [1999, 1941, 1959, 10679, 1987],
}

# Create line plots
plt.figure(figsize=(12, 8))

# Precision
plt.plot(classes, logistic_regression["precision"], marker='o', label='Logistic Regression Precision', color='b')
plt.plot(classes, xgboost["precision"], marker='o', label='XGBoost Precision', color='g')
plt.plot(classes, svm["precision"], marker='o', label='SVM Precision', color='r')
plt.plot(classes, lstm["precision"], marker='o', label='LSTM Precision', color='c')
plt.plot(classes, ensemble["precision"], marker='o', label='Ensemble Precision', color='m')

# Recall
plt.plot(classes, logistic_regression["recall"], marker='x', label='Logistic Regression Recall', linestyle='--', color='b')
plt.plot(classes, xgboost["recall"], marker='x', label='XGBoost Recall', linestyle='--', color='g')
plt.plot(classes, svm["recall"], marker='x', label='SVM Recall', linestyle='--', color='r')
plt.plot(classes, lstm["recall"], marker='x', label='LSTM Recall', linestyle='--', color='c')
plt.plot(classes, ensemble["recall"], marker='x', label='Ensemble Recall', linestyle='--', color='m')

# F1 Score
plt.plot(classes, logistic_regression["f1_score"], marker='s', label='Logistic Regression F1 Score', linestyle='-.', color='b')
plt.plot(classes, xgboost["f1_score"], marker='s', label='XGBoost F1 Score', linestyle='-.', color='g')
plt.plot(classes, svm["f1_score"], marker='s', label='SVM F1 Score', linestyle='-.', color='r')
plt.plot(classes, lstm["f1_score"], marker='s', label='LSTM F1 Score', linestyle='-.', color='c')
plt.plot(classes, ensemble["f1_score"], marker='s', label='Ensemble F1 Score', linestyle='-.', color='m')

# Support (scaled for visualization)
scaled_support = [x / max(ensemble["support"]) for x in logistic_regression["support"]]
plt.plot(classes, scaled_support, marker='d', label='Logistic Regression Support (scaled)', linestyle=':', color='b')

scaled_support = [x / max(ensemble["support"]) for x in xgboost["support"]]
plt.plot(classes, scaled_support, marker='d', label='XGBoost Support (scaled)', linestyle=':', color='g')

scaled_support = [x / max(ensemble["support"]) for x in svm["support"]]
plt.plot(classes, scaled_support, marker='d', label='SVM Support (scaled)', linestyle=':', color='r')

scaled_support = [x / max(ensemble["support"]) for x in lstm["support"]]
plt.plot(classes, scaled_support, marker='d', label='LSTM Support (scaled)', linestyle=':', color='c')

scaled_support = [x / max(ensemble["support"]) for x in ensemble["support"]]
plt.plot(classes, scaled_support, marker='d', label='Ensemble Support (scaled)', linestyle=':', color='m')

# Add details
plt.title("Comparison of Metrics Across Models and Classes", fontweight="bold")
plt.xlabel("Classes", fontweight="bold")
plt.ylabel("Metrics / Scaled Support", fontweight="bold")
plt.xticks(rotation=45)  # Rotate x-axis labels to place them below
plt.grid(True, linestyle='--', alpha=0.7)
plt.tight_layout()

# Move the legend below the plot
plt.legend(loc='upper center', bbox_to_anchor=(0.5, -0.15), ncol=5)

# Show the plot
plt.show()

# %%
import matplotlib.pyplot as plt

# Classes and Metrics
classes = ["Anxiety", "Bipolar", "Depression", "Normal", "PTSD"]

# Model Metrics
logistic_regression = {
    "precision": [0.83, 0.74, 0.76, 0.92, 0.87],
    "recall": [0.77, 0.55, 0.76, 0.99, 0.77],
    "f1_score": [0.80, 0.63, 0.76, 0.95, 0.82],
    "support": [379, 384, 373, 2183, 394],
}

naive_bayes = {
    "precision": [0.69, 0.75, 0.60, 0.96, 0.73],
    "recall": [0.76, 0.55, 0.83, 0.91, 0.79],
    "f1_score": [0.72, 0.64, 0.70, 0.94, 0.76],
    "support": [379, 384, 373, 2183, 394],
}

svm = {
    "precision": [0.72, 0.62, 0.74, 0.94, 0.78],
    "recall": [0.76, 0.61, 0.71, 0.95, 0.74],
    "f1_score": [0.74, 0.61, 0.72, 0.95, 0.76],
    "support": [379, 384, 373, 2183, 394],
}

xgboost = {
    "precision": [0.81, 0.77, 0.72, 0.93, 0.86],
    "recall": [0.74, 0.62, 0.81, 0.98, 0.75],
    "f1_score": [0.77, 0.69, 0.76, 0.95, 0.80],
    "support": [403, 397, 387, 2137, 396],
}

lstm = {
    "precision": [0.81, 0.60, 0.56, 0.96, 0.76],
    "recall": [0.68, 0.59, 0.77, 0.96, 0.61],
    "f1_score": [0.74, 0.60, 0.65, 0.96, 0.68],
    "support": [403, 397, 387, 2137, 396],
}

ensemble = {
    "precision": [0.99, 0.98, 0.98, 1.00, 0.99],
    "recall": [0.98, 0.97, 0.99, 1.00, 0.99],
    "f1_score": [0.99, 0.98, 0.98, 1.00, 0.99],
    "support": [1999, 1941, 1959, 10679, 1987],
}

# Line Plot Setup
plt.figure(figsize=(16, 10))

# Plot metrics for each model
for metric, marker, linestyle in zip(
    ["precision", "recall", "f1_score"],
    ['o', 'x', 's'],
    ['-', '--', '-.']
):
    plt.plot(classes, logistic_regression[metric], marker=marker, label=f'LR {metric.capitalize()}', color='b', linestyle=linestyle)
    plt.plot(classes, naive_bayes[metric], marker=marker, label=f'NB {metric.capitalize()}', color='g', linestyle=linestyle)
    plt.plot(classes, svm[metric], marker=marker, label=f'SVM {metric.capitalize()}', color='r', linestyle=linestyle)
    plt.plot(classes, xgboost[metric], marker=marker, label=f'XGB {metric.capitalize()}', color='c', linestyle=linestyle)
    plt.plot(classes, lstm[metric], marker=marker, label=f'LSTM {metric.capitalize()}', color='m', linestyle=linestyle)
    plt.plot(classes, ensemble[metric], marker=marker, label=f'Ensemble {metric.capitalize()}', color='k', linestyle=linestyle)

# Plot scaled support for visualization
for model, color in zip(
    [logistic_regression, naive_bayes, svm, xgboost, lstm, ensemble],
    ['b', 'g', 'r', 'c', 'm', 'k']
):
    scaled_support = [x / max(ensemble["support"]) for x in model["support"]]
    plt.plot(classes, scaled_support, marker='d', label=f'{color.upper()} Support (scaled)', linestyle=':', color=color)

# Add plot details
plt.title("Comparison of Metrics Across Models and Classes", fontweight="bold", fontsize=14)
plt.xlabel("Classes", fontweight="bold", fontsize=12)
plt.ylabel("Metrics / Scaled Support", fontweight="bold", fontsize=12)
plt.xticks(rotation=45)
plt.grid(alpha=0.5, linestyle='--')
plt.legend(loc='upper center', bbox_to_anchor=(0.5, -0.15), ncol=4, fontsize=10)
plt.tight_layout()

# Show Plot
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# Data for models' classification reports
models = ['EM 1', 'EM 2', 'EM 3', 'EM 4', 'EM 5']
accuracies = [96.09, 99.92, 97.05, 99.19, 94.93]
precision = [0.95, 1.00, 0.96, 0.99, 0.95]  # Weighted average precision
recall = [0.93, 1.00, 0.95, 0.99, 0.91]  # Weighted average recall
f1_score = [0.94, 1.00, 0.95, 0.99, 0.95]  # Weighted average F1-score

# Create a dataframe for easy plotting
import pandas as pd

data = {
    'Model': models,
    'Accuracy': accuracies,
    'Precision': precision,
    'Recall': recall,
    'F1-Score': f1_score
}

df = pd.DataFrame(data)

# Set the seaborn style
sns.set(style="whitegrid")

# Create a figure and set of subplots
fig, ax = plt.subplots(1, 4, figsize=(20, 6))

# Accuracy Barplot
sns.barplot(x='Model', y='Accuracy', data=df, ax=ax[0], palette='Blues_d')
ax[0].set_title('Accuracy Comparison')
ax[0].set_ylim(90, 100)

# Precision Barplot
sns.barplot(x='Model', y='Precision', data=df, ax=ax[1], palette='Greens_d')
ax[1].set_title('Precision Comparison')
ax[1].set_ylim(0, 1)

# Recall Barplot
sns.barplot(x='Model', y='Recall', data=df, ax=ax[2], palette='Reds_d')
ax[2].set_title('Recall Comparison')
ax[2].set_ylim(0, 1)

# F1-Score Barplot
sns.barplot(x='Model', y='F1-Score', data=df, ax=ax[3], palette='Purples_d')
ax[3].set_title('F1-Score Comparison')
ax[3].set_ylim(0, 1)

# Adjust layout and show plot
plt.tight_layout()
plt.show()
# Out:
# <ipython-input-4-a1ecfc70b4a5>:32: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='Model', y='Accuracy', data=df, ax=ax[0], palette='Blues_d')
# <ipython-input-4-a1ecfc70b4a5>:37: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='Model', y='Precision', data=df, ax=ax[1], palette='Greens_d')
# <ipython-input-4-a1ecfc70b4a5>:42: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='Model', y='Recall', data=df, ax=ax[2], palette='Reds_d')
# <ipython-input-4-a1ecfc70b4a5>:47: FutureWarning:
#
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import pandas as pd

# Data for models' classification reports
models = ['Model 1', 'Model 2', 'Model 3', 'Model 4', 'Model 5']
accuracies = [96.09, 99.92, 97.05, 99.19, 94.93]
precision = [0.95, 1.00, 0.96, 0.99, 0.95]  # Weighted average precision
recall = [0.93, 1.00, 0.95, 0.99, 0.91]  # Weighted average recall
f1_score = [0.94, 1.00, 0.95, 0.99, 0.95]  # Weighted average F1-score

# Create a dataframe for easy plotting
data = {
    'Model': models,
    'Accuracy': accuracies,
    'Precision': precision,
    'Recall': recall,
    'F1-Score': f1_score
}

df = pd.DataFrame(data)

# Set the seaborn style
sns.set(style="whitegrid")

# Create a figure with 2 rows and 2 columns of subplots
fig, ax = plt.subplots(2, 2, figsize=(14, 10))

# Accuracy Barplot (Top-Left)
sns.barplot(x='Model', y='Accuracy', data=df, ax=ax[0, 0], palette='Blues_d')
ax[0, 0].set_title('Accuracy Comparison')
ax[0, 0].set_ylim(90, 100)

# Precision Barplot (Top-Right)
sns.barplot(x='Model', y='Precision', data=df, ax=ax[0, 1], palette='Greens_d')
ax[0, 1].set_title('Precision Comparison')
ax[0, 1].set_ylim(0, 1)

# Recall Barplot (Bottom-Left)
sns.barplot(x='Model', y='Recall', data=df, ax=ax[1, 0], palette='Reds_d')
ax[1, 0].set_title('Recall Comparison')
ax[1, 0].set_ylim(0, 1)

# F1-Score Barplot (Bottom-Right)
sns.barplot(x='Model', y='F1-Score', data=df, ax=ax[1, 1], palette='Purples_d')
ax[1, 1].set_title('F1-Score Comparison')
ax[1, 1].set_ylim(0, 1)

# Adjust layout and show plot
plt.tight_layout()
plt.show()
# Out:
# <ipython-input-5-e22ec62fef0c>:31: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='Model', y='Accuracy', data=df, ax=ax[0, 0], palette='Blues_d')
# <ipython-input-5-e22ec62fef0c>:36: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='Model', y='Precision', data=df, ax=ax[0, 1], palette='Greens_d')
# <ipython-input-5-e22ec62fef0c>:41: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='Model', y='Recall', data=df, ax=ax[1, 0], palette='Reds_d')
# <ipython-input-5-e22ec62fef0c>:46: FutureWarning:
#
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Data: Accuracy for each combination
data = {
    'Model': ['Logistic Regression', 'KNN', 'SVC', 'Naive Bayes', 'Random Forest', 'XGB'],
    'BoW': [87.66, 54.56, 85.13, 83.63, 85.32, 87.42],
    'TFIDF': [86.02, 75.06, 88.26, 79.42, 85.73, 87.39],
    'LIWC': [66.36, 70.70, 68.14, 59.63, 76.73, 78.56],
    'Word2Vec': [79.40, 75.52, 77.89, 60.44, 79.88, 81.01],
    'N-Gram': [87.13, 43.06, 84.33, 81.71, 79.02, 87.96]
}

# Create a DataFrame
df = pd.DataFrame(data)

# Plot a grouped bar chart
plt.figure(figsize=(12, 6))
df.set_index('Model').T.plot(kind='bar', figsize=(12, 6), width=0.8)

# Add labels and title
plt.title('Model Performance Comparison', fontsize=14)
plt.xlabel('Feature Extraction Methods', fontsize=12)
plt.ylabel('Accuracy (%)', fontsize=12)
plt.legend(title='Models', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.xticks(rotation=0)
plt.grid(axis='y', linestyle='--', alpha=0.7)

# Show the plot
plt.tight_layout()
plt.show()

# Print the table for reference
print(df)
# Out:
#                  Model    BoW  TFIDF   LIWC  Word2Vec  N-Gram
# 0  Logistic Regression  87.66  86.02  66.36     79.40   87.13
# 1                  KNN  54.56  75.06  70.70     75.52   43.06
# 2                  SVC  85.13  88.26  68.14     77.89   84.33
# 3          Naive Bayes  83.63  79.42  59.63     60.44   81.71
# 4        Random Forest  85.32  85.73  76.73     79.88   79.02
# 5                  XGB  87.42  87.39  78.56     81.01   87.96
